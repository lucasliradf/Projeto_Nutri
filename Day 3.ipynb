# %%
import pandas as pd 
import numpy as np 
import matplotlib as plt
import statistics as stats

# %%
comidas = pd.read_csv("comensais dia 3.csv")
comidas
# Out:
#     Unnamed: 0 Salada 2: Salada de tomate com manjericão  \
# 0            1                                         0
# 1            4                                         0
# 2            8                                         0
# 3           12                                         G
# 4           16                                         M
# 5           20                                         P
# 6           24                                         M
# 7           28                                         G
# 8           32                                         G
# 9           36                                         0
# 10          40                                         M
# 11          44                                         M
# 12          48                                         0
# 13          52                                         G
# 14          56                                         0
# ...

# %%
salada2 = comidas['Salada 2: Salada de tomate com manjericão'].value_counts()
salada3 = comidas['Salada 3: Salada de couve0flor com vinagrete'].value_counts()
salada4 = comidas['Salada 4: Salada de peipino '].value_counts()
arroz = comidas['Arroz branco'].value_counts()
couve = comidas['Virado de couve'].value_counts()
galeto = comidas['Galeto'].value_counts()

print(salada2, salada3, salada4, arroz, couve, galeto)
# Out:
# M    17
# 0    16
# P     9
# G     8
# Name: Salada 2: Salada de tomate com manjericão, dtype: int64 0    28
# P    15
# M     6
# G     1
# Name: Salada 3: Salada de couve0flor com vinagrete, dtype: int64 0    22
# P    21
# M     6
# G     1
# Name: Salada 4: Salada de peipino , dtype: int64 0    33
# M     8
# G     6
# P     3
# Name: Arroz branco, dtype: int64 M    31
# P    10
# G     6
# 0     3
# Name: Virado de couve, dtype: int64 0    32
# P    13
# M     5
# Name: Galeto, dtype: int64

# %%
salada2_p = comidas['Salada 2: Salada de tomate com manjericão'].value_counts()[2]
salada2_m = comidas['Salada 2: Salada de tomate com manjericão'].value_counts()[0]
salada2_g = comidas['Salada 2: Salada de tomate com manjericão'].value_counts()[3]
salada2_sem = comidas['Salada 2: Salada de tomate com manjericão'].value_counts()[1]
salada3_p = comidas['Salada 3: Salada de couve0flor com vinagrete'].value_counts()[1]
salada3_m = comidas['Salada 3: Salada de couve0flor com vinagrete'].value_counts() [2]
salada3_g = comidas['Salada 3: Salada de couve0flor com vinagrete'].value_counts()[3]
salada3_sem = comidas['Salada 3: Salada de couve0flor com vinagrete'].value_counts()[0]
salada4_p = comidas['Salada 4: Salada de peipino '].value_counts()[1]
salada4_m = comidas['Salada 4: Salada de peipino '].value_counts()[2]
salada4_g = comidas['Salada 4: Salada de peipino '].value_counts()[3]
salada4_sem = comidas['Salada 4: Salada de peipino '].value_counts()[0]
arroz_p = comidas['Arroz branco'].value_counts()[3]
arroz_m = comidas['Arroz branco'].value_counts()[1]
arroz_g = comidas['Arroz branco'].value_counts()[2]
arroz_sem = comidas['Arroz branco'].value_counts()[0]
couve_p = comidas['Virado de couve'].value_counts()[1]
couve_m = comidas['Virado de couve'].value_counts()[0]
couve_g = comidas['Virado de couve'].value_counts()[2]
couve_sem = comidas['Virado de couve'].value_counts()[3]
galeto_p = comidas['Galeto'].value_counts()[1]
galeto_m = comidas['Galeto'].value_counts()[2]
galeto_g = 0
galeto_sem = comidas['Galeto'].value_counts()[0]

# %%
comidas['Salada 2: Salada de tomate com manjericão'].replace({'P': 40, 'M': 70, 'G': 100, 'Null': 0}, inplace = True)
comidas['Salada 3: Salada de couve0flor com vinagrete'].replace({'P': 70, 'M': 120, 'G': 180, 'N': 0}, inplace = True)
comidas['Salada 4: Salada de peipino '].replace({'P': 40, 'M': 50, 'G': 80, 'N': 0}, inplace = True)
comidas['Arroz branco'].replace({'P': 50, 'M': 100, 'G':160, 'N': 0}, inplace = True)
comidas['Virado de couve'].replace({'P': 50, 'M': 120, 'G': 180, 'N': 0}, inplace = True)
comidas['Galeto'].replace({'P': 80, 'M': 180, 'G':270, 'N': 0}, inplace = True)

# %%
comidas
# Out:
#     Unnamed: 0 Salada 2: Salada de tomate com manjericão  \
# 0            1                                         0
# 1            4                                         0
# 2            8                                         0
# 3           12                                       100
# 4           16                                        70
# 5           20                                        40
# 6           24                                        70
# 7           28                                       100
# 8           32                                       100
# 9           36                                         0
# 10          40                                        70
# 11          44                                        70
# 12          48                                         0
# 13          52                                       100
# 14          56                                         0
# ...

# %%
comidas.dtypes
# Out:
# Unnamed: 0                                       int64
# Salada 2: Salada de tomate com manjericão       object
# Salada 3: Salada de couve0flor com vinagrete    object
# Salada 4: Salada de peipino                     object
# Arroz branco                                    object
# Virado de couve                                 object
# Galeto                                          object
# dtype: object

# %%
comidas.describe()
# Out:
#        Unnamed: 0
# count   50.000000
# mean    98.020000
# std     58.275381
# min      1.000000
# 25%     49.000000
# 50%     98.000000
# 75%    147.000000
# max    196.000000

# %%
comidas.dtypes
# Out:
# Unnamed: 0                                      object
# Salada 2: Salada de tomate com manjericão       object
# Salada 3: Salada de couve0flor com vinagrete    object
# Salada 4: Salada de peipino                     object
# Arroz branco                                    object
# Virado de couve                                 object
# Galeto                                          object
# dtype: object

# %%
comidas['Salada 2: Salada de tomate com manjericão'] = comidas['Salada 2: Salada de tomate com manjericão'].astype(int)
comidas['Salada 2: Salada de tomate com manjericão'] = comidas['Salada 2: Salada de tomate com manjericão'].astype(int)
comidas['Salada 3: Salada de couve0flor com vinagrete'] = comidas['Salada 3: Salada de couve0flor com vinagrete'].astype(int)
comidas['Salada 4: Salada de peipino '] = comidas['Salada 4: Salada de peipino '].astype(int)
comidas['Arroz branco'] = comidas['Arroz branco'].astype(int)
comidas['Virado de couve'] = comidas['Virado de couve'].astype(int)
comidas['Galeto'] = comidas['Galeto'].astype(int)

# %%
comidas.dtypes
# Out:
# Unnamed: 0                                      int64
# Salada 2: Salada de tomate com manjericão       int32
# Salada 3: Salada de couve0flor com vinagrete    int32
# Salada 4: Salada de peipino                     int32
# Arroz branco                                    int32
# Virado de couve                                 int32
# Galeto                                          int32
# dtype: object

# %%
comidas.mean()
# Out:
# Unnamed: 0                                       98.02
# Salada 2: Salada de tomate com manjericão        47.00
# Salada 3: Salada de couve0flor com vinagrete     39.00
# Salada 4: Salada de peipino                      24.40
# Arroz branco                                     38.20
# Virado de couve                                 106.00
# Galeto                                           38.80
# dtype: float64

# %%
Media_salada2 = round((comidas['Salada 2: Salada de tomate com manjericão'].sum()/34), 2) 
media_salada3 = round((comidas['Salada 3: Salada de couve0flor com vinagrete'].sum()/22), 2)
media_salada4 = round((comidas['Salada 4: Salada de peipino '].sum()/28), 2)
media_arroz = round((comidas['Arroz branco'].sum()/17), 2)
media_couve = round((comidas['Virado de couve'].sum()/19), 2)
media_galeto = round((comidas['Galeto'].sum()/18), 2)

print(Media_salada2, media_salada3, media_salada4, media_arroz, media_couve, media_galeto)
# Out:
# 69.12 88.64 43.57 112.35 278.95 107.78
