# %%
# %%time
import pandas as pd 
import numpy as np 
import matplotlib as plt
# Out:
# Wall time: 0 ns

# %%
pmedia = pd.read_csv('PORCIONAMENTO MÉDIAS dia 1.csv')
pmedia
# Out:
#   Tamano  Arroz branco  Arroz integral  Feijao preto  Galeto  Creme de milho  \
# 0      P            50              50           120      80              50
# 1      M           100             110           220     180             110
# 2      G           160             170           300     270             200
#
#    Banana  Salada 1 (mix de folhas)  \
# 0     150                        30
# 1     290                        50
# 2     470                        80
#
#    Salada 2 (Salada de tomate cereja com cebola roxa)  \
# 0                                                 30
# 1                                                 80
# 2                                                130
#
#    Salada 3 (Salada de conserva de mini batatas)  \
# 0                                             60
# 1                                            120
# 2                                            190
#
#    Salada 4 (Salada de abobrinha com brocolis)
# ...

# %%
comida = pd.read_csv('PORCIONAMENTO COMENSAIS DIA 1.csv')
comida
# Out:
#      ID Salada 1: Salada de alface crespa com chicória e repolho branco  \
# 0     1                                                  P
# 1     4                                                  P
# 2     8                                                  M
# 3    12                                                  G
# 4    16                                                  P
# 5    20                                                  P
# 6    24                                                  P
# 7    28                                                  P
# 8    32                                                  P
# 9    36                                                  M
# 10   40                                                  P
# 11   44                                                  0
# 12   48                                                  P
# 13   52                                                  G
# 14   56                                                  M
# ...

# %%
comida['Salada 1: Salada de alface crespa com chicória e repolho branco'].value_counts()
# Out:
# P    22
# M    16
# 0     9
# G     3
# Name: Salada 1: Salada de alface crespa com chicória e repolho branco, dtype: int64

# %%
psalada1 = comida['Salada 1: Salada de alface crespa com chicória e repolho branco'].value_counts()[0] * 30
msalada1 = comida['Salada 1: Salada de alface crespa com chicória e repolho branco'].value_counts()[1] * 50
gsalada1 = comida['Salada 1: Salada de alface crespa com chicória e repolho branco'].value_counts()[3] * 80

print(psalada1, msalada1, gsalada1)
# Out:
# 660 800 240

# %%
quantidade_salada1 = comida['Salada 1: Salada de alface crespa com chicória e repolho branco'].value_counts()
qnt_Salada1_P = comida['Salada 1: Salada de alface crespa com chicória e repolho branco'].value_counts()[0]
qnt_Salada1_M = comida['Salada 1: Salada de alface crespa com chicória e repolho branco'].value_counts()[1]
qnt_Salada1_G = comida['Salada 1: Salada de alface crespa com chicória e repolho branco'].value_counts()[3]
qnt_Salada1_sem = comida['Salada 1: Salada de alface crespa com chicória e repolho branco'].value_counts()[2]
media_salada1 = (psalada1 + msalada1 + gsalada1)/50
media_salada1
print('n pedidos:', quantidade_salada1,
      'media=', media_salada1)

print(qnt_Salada1_P, qnt_Salada1_M, qnt_Salada1_G, qnt_Salada1_sem)
# Out:
# n pedidos: P    22
# M    16
# 0     9
# G     3
# Name: Salada 1: Salada de alface crespa com chicória e repolho branco, dtype: int64 media= 34.0
# 22 16 3 9

# %%
quantidade_salada2 = comida['Salada 2: Salada de tomate cereja com cebola roxa'].value_counts()
psalada2 = comida['Salada 2: Salada de tomate cereja com cebola roxa'].value_counts()[0] * 30 + comida['Salada 2: Salada de tomate cereja com cebola roxa'].value_counts()[3] * 30
msalada2 = comida['Salada 2: Salada de tomate cereja com cebola roxa'].value_counts()[1] * 80

qnt_Salada2_P = comida['Salada 2: Salada de tomate cereja com cebola roxa'].value_counts()[0] + comida['Salada 2: Salada de tomate cereja com cebola roxa'].value_counts()[3]
qnt_Salada2_M = comida['Salada 2: Salada de tomate cereja com cebola roxa'].value_counts()[1]
qnt_Salada2_G = 0
qnt_Salada2_sem = comida['Salada 2: Salada de tomate cereja com cebola roxa'].value_counts()[2]

print(qnt_Salada2_P, qnt_Salada2_M, qnt_Salada2_G, qnt_Salada2_sem)

print(quantidade_salada2, psalada2, msalada2)

media_salada2 = (psalada2 + msalada2)/50

media_salada2
# Out:
# 30 15 0 5
# P    29
# M    15
# 0     5
# p     1
# Name: Salada 2: Salada de tomate cereja com cebola roxa, dtype: int64 900 1200
# 42.0

# %%
quantidade_salada3 = comida['Salada 3: Salada de conserva de mini batatas'].value_counts()
psalada3 = comida['Salada 3: Salada de conserva de mini batatas'].value_counts()[1] * 60 + comida['Salada 3: Salada de conserva de mini batatas'].value_counts()[3] * 60
msalada3 = comida['Salada 3: Salada de conserva de mini batatas'].value_counts()[2] * 120

qnt_Salada3_P = comida['Salada 3: Salada de conserva de mini batatas'].value_counts()[1] + comida['Salada 3: Salada de conserva de mini batatas'].value_counts()[3]
qnt_Salada3_M = comida['Salada 3: Salada de conserva de mini batatas'].value_counts()[3]
qnt_Salada3_G = 0
qnt_Salada3_sem = comida['Salada 3: Salada de conserva de mini batatas'].value_counts()[0]


print(qnt_Salada3_P, qnt_Salada3_M, qnt_Salada3_G, qnt_Salada3_sem)





print(quantidade_salada3, psalada3, msalada3)

media_salada3 = (psalada3 + msalada3)/50

media_salada3
# Out:
# 18 1 0 27
# 0    27
# P    17
# M     5
# p     1
# Name: Salada 3: Salada de conserva de mini batatas, dtype: int64 1080 600
# 33.6

# %%
quantidade_salada4 = comida['Salada 4: Salada de abobrinha com brócolis '].value_counts()
qnt_salada4_p = comida['Salada 4: Salada de abobrinha com brócolis '].value_counts()[0]
qnt_salada4_m = comida['Salada 4: Salada de abobrinha com brócolis '].value_counts()[2] + comida['Salada 4: Salada de abobrinha com brócolis '].value_counts()[4]
qnt_salada4_g = comida['Salada 4: Salada de abobrinha com brócolis '].value_counts()[3]
qnt_salada4_sem = comida['Salada 4: Salada de abobrinha com brócolis '].value_counts()[1]
print(qnt_salada4_p, qnt_salada4_m, qnt_salada4_g, qnt_salada4_sem)


print(quantidade_salada4, psalada4, msalada4, gsalada4)

media_salada4 = (psalada4 + msalada4 + gsalada4)/50

media_salada4
# Out:
# 18 15 2 15
# P     18
# 0     15
# M     14
# G      2
# ,M     1
# Name: Salada 4: Salada de abobrinha com brócolis , dtype: int64 720 1800 400
# 58.4

# %%
quantidade_arroz_branco = comida['Arroz branco'].value_counts()
qnt_p_arroz_branco = comida['Arroz branco'].value_counts()[3]
qnt_m_arroz_branco = comida['Arroz branco'].value_counts()[1]
qnt_g_arroz_branco = comida['Arroz branco'].value_counts()[2]
qnt_sem_arroz_branco = comida['Arroz branco'].value_counts()[0]

print(qnt_p_arroz_branco, qnt_m_arroz_branco, qnt_g_arroz_branco, qnt_sem_arroz_branco)

print(quantidade_arroz_branco, p_arroz_branco, m_arroz_branco, g_arroz_branco)

media_arroz_branco = (p_arroz_branco + m_arroz_branco + g_arroz_branco)/50

media_arroz_branco
# Out:
# 5 14 6 25
# 0    25
# M    14
# G     6
# P     5
# Name: Arroz branco, dtype: int64 250 1400 960
# 52.2

# %%
quantidade_Arroz_integral = comida['Arroz integral'].value_counts()
qnt_p_Arroz_integral = comida['Arroz integral'].value_counts()[1]
qnt_m_Arroz_integral = comida['Arroz integral'].value_counts()[2]
qnt_g_Arroz_integral = comida['Arroz integral'].value_counts()[3] 
qnt_sem_Arroz_integral = comida['Arroz integral'].value_counts()[0] 
print(qnt_p_Arroz_integral, qnt_m_Arroz_integral, qnt_g_Arroz_integral, qnt_sem_Arroz_integral)

print(quantidade_Arroz_integral,'--',
      p_Arroz_integral, m_Arroz_integral , g_Arroz_integral)

media_Arroz_integral = (p_Arroz_integral + m_Arroz_integral + g_Arroz_integral)/50

media_Arroz_integral
# Out:
# 11 7 3 29
# 0    29
# P    11
# M     7
# G     3
# Name: Arroz integral, dtype: int64 -- 550 770 510
# 36.6

# %%
quantidade_feijao_preto = comida['Feijao preto '].value_counts()
qnt_p_feijao_preto = comida['Feijao preto '].value_counts()[0]
qnt_m_feijao_preto = comida['Feijao preto '].value_counts()[2]
qnt_g_feijao_preto = 0
qnt_sem_feijao_preto = comida['Feijao preto '].value_counts()[1]


print(qnt_p_feijao_preto, qnt_m_feijao_preto, qnt_g_feijao_preto, qnt_sem_feijao_preto)

print(quantidade_feijao_preto,'--',
      p_feijao_preto, m_feijao_preto)

media__feijao_preto = (p_feijao_preto + m_feijao_preto)/50

media__feijao_preto
# Out:
# 27 7 0 16
# P    27
# 0    16
# M     7
# Name: Feijao preto , dtype: int64 -- 3240 1540
# 95.6

# %%
quantidade_galeto = comida['Galeto'].value_counts()
qnt_p_galeto = comida['Galeto'].value_counts()[1] 
qnt_m_galeto = comida['Galeto'].value_counts()[0] + comida['Galeto'].value_counts()[5]
qnt_g_galeto = comida['Galeto'].value_counts()[2] + comida['Galeto'].value_counts()[4]
qnt_sem_galeto = comida['Galeto'].value_counts()[3]

print(qnt_p_galeto, qnt_m_galeto, qnt_g_galeto, qnt_sem_galeto)

print(quantidade_galeto,'--',
      p_galeto, m_galeto , g_galeto)

media_galeto = (p_galeto + m_galeto + g_galeto)/50

media_galeto
# Out:
# 16 26 7 1
# M     25
# P     16
# G      6
# 0      1
# G      1
#  M     1
# Name: Galeto, dtype: int64 -- 1280 4680 1890
# 157.0

# %%
quantidade_creme_de_milho = comida['Creme de milho'].value_counts()
qnt_p_creme_de_milho = comida['Creme de milho'].value_counts()[1] 
qnt_m_creme_de_milho = comida['Creme de milho'].value_counts()[0] 
qnt_g_creme_de_milho = comida['Creme de milho'].value_counts()[3] 
qnt_sem_creme_de_milho = comida['Creme de milho'].value_counts()[2]

print(qnt_p_creme_de_milho,qnt_m_creme_de_milho, qnt_g_creme_de_milho, qnt_sem_creme_de_milho)
print(quantidade_creme_de_milho,'--',
      p_creme_de_milho, m_creme_de_milho , g_creme_de_milho)

media_creme_de_milho = (p_creme_de_milho + m_creme_de_milho + g_creme_de_milho)/50

media_creme_de_milho
# Out:
# 14 23 4 9
# M    23
# P    14
# 0     9
# G     4
# Name: Creme de milho, dtype: int64 -- 700 2530 800
# 80.6

# %%
quantidade_banana = comida['Banana'].value_counts()
qnt_p_banana = comida['Banana'].value_counts()[0] 
qnt_m_banana = comida['Banana'].value_counts()[2] 
qnt_g_banana = 0
qnt_sem_banana = comida['Banana'].value_counts()[1]
print(qnt_p_banana, qnt_m_banana, qnt_g_banana, qnt_sem_banana)
print(quantidade_banana,'--',
      p_banana, m_banana)

media_banana = (p_banana + m_banana)/50

media_banana
# Out:
# 32 4 0 14
# P    32
# 0    14
# M     4
# Name: Banana, dtype: int64 -- 4800 1160
# 119.2

# %%
teste = pd.DataFrame.from_dict(data={'Medidas': ['Porções P', 'Porções M', 'Porções G', 'Sem Porção', 'Media'],
    'Salada1': [qnt_Salada1_P, qnt_Salada1_M, qnt_Salada1_G, qnt_Salada1_sem, media_salada1], 
                           'Salada2': [qnt_Salada2_P, qnt_Salada2_M, qnt_Salada2_G, qnt_Salada2_sem, media_salada2], 
                           'salada3': [qnt_Salada3_P, qnt_Salada3_M, qnt_Salada3_G, qnt_Salada3_sem, media_salada3], 
                           'salada4': [qnt_salada4_p, qnt_salada4_m, qnt_salada4_g, qnt_salada4_sem, media_salada4],
                           'arroz branco': [qnt_p_arroz_branco, qnt_m_arroz_branco, qnt_g_arroz_branco, qnt_sem_arroz_branco, media_arroz_branco], 
                           'arroz integral': [qnt_p_Arroz_integral, qnt_m_Arroz_integral, qnt_g_Arroz_integral, qnt_sem_Arroz_integral, media_Arroz_integral],
                           'feijao preto': [qnt_p_feijao_preto, qnt_m_feijao_preto, qnt_g_feijao_preto, qnt_sem_feijao_preto, media__feijao_preto],
                           'creme de milho': [qnt_p_creme_de_milho,qnt_m_creme_de_milho, qnt_g_creme_de_milho, qnt_sem_creme_de_milho, media_creme_de_milho],
                           'galeto': [qnt_p_galeto, qnt_m_galeto, qnt_g_galeto, qnt_sem_galeto, media_galeto],
                           'banana': [qnt_p_banana, qnt_m_banana, qnt_g_banana, qnt_sem_banana, media_banana]})
                            


teste
# Out:
#       Medidas  Salada1  Salada2  salada3  salada4  arroz branco  \
# 0   Porções P     22.0     30.0     18.0     18.0           5.0
# 1   Porções M     16.0     15.0      1.0     15.0          14.0
# 2   Porções G      3.0      0.0      0.0      2.0           6.0
# 3  Sem Porção      9.0      5.0     27.0     15.0          25.0
# 4       Media     34.0     42.0     33.6     58.4          52.2
#
#    arroz integral  feijao preto  creme de milho  galeto  banana
# 0            11.0          27.0            14.0    16.0    32.0
# 1             7.0           7.0            23.0    26.0     4.0
# 2             3.0           0.0             4.0     7.0     0.0
# 3            29.0          16.0             9.0     1.0    14.0
# 4            36.6          95.6            80.6   157.0   119.2
